# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("C:/Users/jugvi/Downloads/Train2.csv")

# %%
df.head()
# Out:
#        ID  Gender Ever_Married  Age Graduated     Profession  Work_Experience  \
# 0  462809    Male           No   22        No     Healthcare              1.0
# 1  462643  Female          Yes   38       Yes       Engineer              NaN
# 2  466315  Female          Yes   67       Yes       Engineer              1.0
# 3  461735    Male          Yes   67       Yes         Lawyer              0.0
# 4  462669  Female          Yes   40       Yes  Entertainment              NaN
#
#   Spending_Score  Family_Size  Var_1
# 0            Low          4.0  Cat_4
# 1        Average          3.0  Cat_4
# 2            Low          1.0  Cat_6
# 3           High          2.0  Cat_6
# 4           High          6.0  Cat_6

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8068 entries, 0 to 8067
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ID               8068 non-null   int64
#  1   Gender           8068 non-null   object
#  2   Ever_Married     7928 non-null   object
#  3   Age              8068 non-null   int64
#  4   Graduated        7990 non-null   object
#  5   Profession       7944 non-null   object
#  6   Work_Experience  7239 non-null   float64
#  7   Spending_Score   8068 non-null   object
#  8   Family_Size      7733 non-null   float64
#  9   Var_1            7992 non-null   object
# dtypes: float64(2), int64(2), object(6)
# memory usage: 630.4+ KB

# %% [markdown]
#  Data Cleaning

# %%
df.isna().sum()
# Out:
# ID                   0
# Gender               0
# Ever_Married       140
# Age                  0
# Graduated           78
# Profession         124
# Work_Experience    829
# Spending_Score       0
# Family_Size        335
# Var_1               76
# dtype: int64

# %%
df['Ever_Married'].mode()
# Out:
# 0    Yes
# dtype: object

# %%
df['Graduated'].mode()
# Out:
# 0    Yes
# dtype: object

# %%
df['Profession'].mode()
# Out:
# 0    Artist
# dtype: object

# %%
df['Work_Experience'].mode()
# Out:
# 0    1.0
# dtype: float64

# %%
df['Family_Size'].mode()
# Out:
# 0    2.0
# dtype: float64

# %%
val = {'Ever_Married':'Yes','Graduated':'Yes','Profession':'Artist','Work_Experience':1.0,'Family_Size':2.0}

# %%
df.fillna(value = val,inplace=True)

# %%
df.head()
# Out:
#        ID  Gender Ever_Married  Age Graduated     Profession  Work_Experience  \
# 0  462809    Male           No   22        No     Healthcare              1.0
# 1  462643  Female          Yes   38       Yes       Engineer              1.0
# 2  466315  Female          Yes   67       Yes       Engineer              1.0
# 3  461735    Male          Yes   67       Yes         Lawyer              0.0
# 4  462669  Female          Yes   40       Yes  Entertainment              1.0
#
#   Spending_Score  Family_Size  Var_1
# 0            Low          4.0  Cat_4
# 1        Average          3.0  Cat_4
# 2            Low          1.0  Cat_6
# 3           High          2.0  Cat_6
# 4           High          6.0  Cat_6

# %%
df.isna().sum()
# Out:
# ID                  0
# Gender              0
# Ever_Married        0
# Age                 0
# Graduated           0
# Profession          0
# Work_Experience     0
# Spending_Score      0
# Family_Size         0
# Var_1              76
# dtype: int64

# %%
df.drop(['ID','Var_1'],axis=1,inplace=True)

# %%
df.describe()
# Out:
#                Age  Work_Experience  Family_Size
# count  8068.000000      8068.000000  8068.000000
# mean     43.466906         2.472980     2.814824
# std      16.711696         3.265248     1.508841
# min      18.000000         0.000000     1.000000
# 25%      30.000000         0.000000     2.000000
# 50%      40.000000         1.000000     2.000000
# 75%      53.000000         4.000000     4.000000
# max      89.000000        14.000000     9.000000

# %% [markdown]
#  EDA

# %%
sns.displot(data=df,x='Age',kde=True,discrete=True)

# %%
sns.displot(data=df,x='Work_Experience',kde=True)

# %%
sns.displot(data=df,x='Family_Size',kde=True)

# %%
df.groupby('Gender').size().plot(kind='pie',autopct='%.2f',ylabel='Gender')
# Out:
# <AxesSubplot:ylabel='Gender'>

# %%
df.groupby('Ever_Married').size().plot(kind='pie',autopct='%.2f',ylabel='Ever Married?')
# Out:
# <AxesSubplot:ylabel='Ever Married?'>

# %%
df.groupby('Graduated').size().plot(kind='pie',autopct='%.2f',ylabel='Graduated')
# Out:
# <AxesSubplot:ylabel='Graduated'>

# %%
df.groupby('Profession').size().plot(kind='pie',autopct='%.2f',ylabel='')
# Out:
# <AxesSubplot:>

# %%
a = sns.countplot(data=df,x='Profession')
a.set_xticklabels(a.get_xticklabels(), rotation=40, ha="right")
plt.tight_layout()
plt.show()

# %%
sns.countplot(data=df,x='Spending_Score')
# Out:
# <AxesSubplot:xlabel='Spending_Score', ylabel='count'>

# %%
df.boxplot(column='Family_Size')
# Out:
# <AxesSubplot:>

# %%
df.boxplot(column='Work_Experience')
# Out:
# <AxesSubplot:>

# %%
df.boxplot(column='Age')
# Out:
# <AxesSubplot:>

# %%
sns.countplot(data=df,x='Gender',hue='Spending_Score')
# Out:
# <AxesSubplot:xlabel='Gender', ylabel='count'>

# %%
sns.countplot(data=df,x='Gender',hue='Ever_Married')
# Out:
# <AxesSubplot:xlabel='Gender', ylabel='count'>

# %%
b = sns.countplot(data=df,x='Profession',hue='Gender')
b.set_xticklabels(b.get_xticklabels(), rotation=40, ha="right")
plt.tight_layout()
plt.show()

# %%
c = sns.countplot(data=df,x='Profession',hue='Spending_Score')
c.set_xticklabels(c.get_xticklabels(), rotation=40, ha="right")
plt.tight_layout()
plt.show()

# %%
d = sns.countplot(data=df,x='Profession',hue='Ever_Married')
d.set_xticklabels(d.get_xticklabels(), rotation=40, ha="right")
plt.tight_layout()
plt.show()

# %%
e = sns.countplot(data=df,x='Profession',hue='Graduated')
e.set_xticklabels(e.get_xticklabels(), rotation=40, ha="right")
plt.tight_layout()
plt.show()

# %%
sns.countplot(data=df,x='Spending_Score',hue='Graduated')
# Out:
# <AxesSubplot:xlabel='Spending_Score', ylabel='count'>

# %%
sns.countplot(data=df,x='Spending_Score',hue='Ever_Married')
# Out:
# <AxesSubplot:xlabel='Spending_Score', ylabel='count'>

# %%
sns.catplot(x = 'Spending_Score', y = 'Age', hue = 'Gender', alpha = .5, data = df)

# %%
sns.boxplot(x = 'Spending_Score', y = 'Age', data = df)
# Out:
# <AxesSubplot:xlabel='Spending_Score', ylabel='Age'>

# %%
sns.boxplot(x = 'Spending_Score', y = 'Work_Experience', data = df)
# Out:
# <AxesSubplot:xlabel='Spending_Score', ylabel='Work_Experience'>

# %%
sns.boxplot(x = 'Spending_Score', y = 'Family_Size', data = df)
# Out:
# <AxesSubplot:xlabel='Spending_Score', ylabel='Family_Size'>
